# %% [markdown]
# <a href="https://colab.research.google.com/github/viett887g/numpyhocmay/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Cho v là 1 vector hàng

# %%
import random as rd
import numpy as np

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
v=np.array([1,3,4,5,8])
print(v)
# Out:
# [1 3 4 5 8]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
w=np.array([[1],
         [2],
         [3]])
print(w)
# Out:
# [[1]
#  [2]
#  [3]]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print(v.ndim)
print(w.ndim)
#thay dc w co 2 chieu con v chi co 1 chieu
# Out:
# 1
# 2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
u=np.array([[4],
         [5],
         [6]])

# %%
uw=np.column_stack((u,w))
print(uw)
# Out:
# [[4 1]
#  [5 2]
#  [6 3]]

# %%
print(uw.shape)
print(uw.ndim)
# Out:
# (3, 2)
# 2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
X=np.array([2,3,4,5,6,7])

# %%
X= X.reshape((2, 3))
print(X)
# Out:
# [[2 3 4]
#  [5 6 7]]

# %%
print(X.shape)
print(X.ndim)
# Out:
# (2, 3)
# 2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a = [[1, 2], [3, 4]]
b = [[5, 6], [7, 8]]
c=np.dot(a, b)
print(c)
# Out:
# [[19 22]
#  [43 50]]

# %%
print(c.ndim)
print(c.shape)
# Out:
# 2
# (2, 2)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
Xw= np.dot(X,w)
print(Xw)
# Out:
# [[20]
#  [38]]

# %%
print(Xw.shape)
print(Xw.ndim)
# Out:
# (2, 1)
# 2

# %%
#ở câu 6 ma trận 2x2 nhân với ma trận 2x2 nên tao ra ma trận 2x2
# còn ở câu 7 ma trận 2x3 nhân vơi ma trận 3X1 nên tao ra ma trận 2x1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
Xt= X.T
print(Xt)
# Out:
# [[2 5]
#  [3 6]
#  [4 7]]
